# %%
import numpy as np                  # to do math
from astropy.io import fits         # handline .fits files
import pandas as pd                 # table format
import os                           # universal os
from astroquery.sdss import SDSS    # to query SDSS spectra
import matplotlib.pyplot as plt     # for plotting

# %% [markdown]
# ## Load in initial VMS subsample

# %%
filename = 'initial_VMS_eBOSS.csv'            # give the dataframe a name
path = os.path.join('..','subsamples', filename)  # path to dataframe

initial_VMS_eBOSS = pd.read_csv(path)
initial_VMS_eBOSS

# %% [markdown]
# # Removing contaminants: Wolf-Rayet Galaxies
#
# ... still working on this next step ...
#
# Cut galaxies from this initial VMS candidate sample that have an additional Wolf-Rayet spectral features that are not typical of VMS spectra.

# %%
WR_mask = (

    ?  # ~~~~~~ experiment ~~~~~~~~
)

final_VMS_eBOSS = initial_VMS_eBOSS[WR_mask]
len(final_VMS_eBOSS)  # let's see the size of this new sample

# %%
# ~~~~~~~ try plotting some spectra for this subsample ! ~~~~~~~

# %%
# saving this initial VMS subsample for future reference
# final_VMS_eBOSS.to_csv('../subsamples/final_VMS_eBOSS.csv', index=False)
