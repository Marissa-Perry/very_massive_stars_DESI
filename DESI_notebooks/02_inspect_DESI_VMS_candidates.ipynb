# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt           # for plotting
import pandas as pd                       # for data manipulation
import os                                 # for file paths

# %% [markdown]
# ## Load in VMS candidates

# %%
filename = 'DESI_vms_candidates.csv'        # give the dataframe a name
path = os.path.join('..', 'subsamples', filename)  # path to dataframe

desi_sample = pd.read_csv(path)
desi_sample
# Out:
#                  targetid   target_ra  target_dec         z  heii_4686_flux  \
# 0     2305843041057037638  272.089109   -1.142434  0.297237    19906.088000
# 1     2305843041056850482  272.465992   -0.830448  0.372828    19731.775000
# 2     2305843041057102923  273.423802   -1.186909  0.449643     7687.383000
# 3     2305843041061401395  274.250058   -1.076078  0.449482    15221.553000
# 4     2305843041056901022  272.316440   -1.850930  0.265760     9344.481000
# ...                   ...         ...         ...       ...             ...
# 3994    39628291182695149  256.782539   21.271276  0.444177        8.782219
# 3995     2842599282966528  184.723114    2.992279  0.022047       12.459023
# 3996    39627799228581085  144.318710    0.462227  0.368934        5.405819
# 3997    39633075990170706  109.894527   40.094629  0.256709       14.154432
# 3998    39632946117740117  205.219723   33.147285  0.249142       18.339470
#
# ...

# %%
len(desi_sample)  # how many galaxies in our sample ?
# Out:
# 3999

# %% [markdown]
# ## Inspect spectra for these VMS candidates

# %%
source_data = desi_sample.iloc[0]  # saving data for a single galaxy
source_data
# Out:
# targetid                                             2305843041057037638
# target_ra                                                     272.089109
# target_dec                                                     -1.142434
# z                                                               0.297237
# heii_4686_flux                                                 19906.088
# heii_4686_flux_ivar                                             0.000091
# heii_4686_snr                                                 189.979487
# hbeta_flux                                                     20443.232
# hbeta_flux_ivar                                                 0.000088
# oiii_5007_flux                                                   19680.5
# oiii_5007_flux_ivar                                             0.000084
# halpha_flux                                                    14039.785
# halpha_flux_ivar                                                0.000225
# ...

# %%
# try plotting the spectrum for this galaxy !
