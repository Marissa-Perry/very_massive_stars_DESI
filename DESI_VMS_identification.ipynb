# %%
import numpy as np                        # for math
import pandas as pd                       # for data manipulation
import matplotlib.pyplot as plt           # for plotting

from dl import queryClient as qc          # for querying data
from sparcl.client import SparclClient    # ''
from astropy.convolution import convolve, Gaussian1DKernel  # for smoothing spectra

client = SparclClient()  # initialize SPARCL client for querying data
# Out:
# announcement=Data set deprecation notice: on November 19, 2025 the SDSS/BOSS DR16 data sets were deprecated. Please use the new SDSS/BOSS DR17 data sets instead.

# %%
print(qc.schema("desi_dr1"))
# Out:
# Schema: desi_dr1
#
#       Table Name   Description
#       ----------   -----------
#           agngal   Value-Added Catalog of DESI DR1 galaxies and quasars with
#                    spectral and infrared classification diagnostics (17,995,5
#                    99 rows)
#            emfit   Emission-Line flux and width measurements for low-redshift
#                    (z <= 0.45) sources in DR1 (7,378,347 rows)
#         exposure   Summary quantities for every DESI exposure (9,176 rows)
#      fiberassign   Quantities obtained when a DESI target is assigned to a fi
#                    ber (25,061,082 rows)
#            frame   Summary quantities for each petal of the DESI instrument i
#                    n a given exposure; in normal operation there are ten fram
#                    es for every exposure (269,960 rows)
#              mws   Milky Way Survey Value-Added Catalog (6,372,607 rows)
#       photometry   Photometric quantities from LS DR9 for every TARGETID (76,
#                    001,458 rows)
#        potential   For a given tile, this table lists all targets that could
#                    have received a fiber assignment (168,392,774 rows)
#           target   The quantities obtained when photometric objects are analy
#                    zed in the target selection process (151,418,861 rows)
#             tile   Summary quantities for every DESI tile (pointing on the sk
#                    y) (6,101 rows)
# x1p5__zpix__allwise__source   desi_dr1.zpix and allwise.source crossmatch (1.5 arcsec) (
#                    13,807,049 rows)
# x1p5__zpix__gaia_dr3__gaia_source   desi_dr1.zpix and gaia_dr3.gaia_source crossmatch (1.5 arc
#                    sec) (7,198,343 rows)
# x1p5__zpix__nsc_dr2__object   desi_dr1.zpix and nsc_dr2.object crossmatch (1.5 arcsec) (
#                    21,030,574 rows)
# x1p5__zpix__sdss_dr17__specobj   desi_dr1.zpix and sdss_dr17.specobj crossmatch (1.5 arcsec
#                    ) (1,426,308 rows)
# x1p5__zpix__unwise_dr1__object   desi_dr1.zpix and unwise_dr1.object crossmatch (1.5 arcsec
#                    ) (16,530,167 rows)
#             zpix   Redshift and other quantities for spectra that have been g
#                    rouped and coadded by HEALPixel (23,060,727 rows)
#            ztile   Redshift and other quantities for spectra that have been g
#                    rouped and coadded by tile (24,896,930 rows)

# %%
print(qc.schema("desi_dr1.zpix"))
# Out:
# Schema: desi_dr1
#  Table: zpix
#
#      Column Name   Description
#      -----------   -----------
#                z   Redshift measured by Redrock
#             zerr   Redshift error from Redrock
#             chi2   Best fit chi squared
#          coeff_0   Redrock template coefficients
#          coeff_1   Redrock template coefficients
#          coeff_2   Redrock template coefficients
#          coeff_3   Redrock template coefficients
#          coeff_4   Redrock template coefficients
#          coeff_5   Redrock template coefficients
#          coeff_6   Redrock template coefficients
#          coeff_7   Redrock template coefficients
#          coeff_8   Redrock template coefficients
#          coeff_9   Redrock template coefficients
#        deltachi2   Delta-chi-squared for template fit from Redrock
#    mean_fiber_ra   Mean (over exposures) RA of actual fiber position
#   mean_fiber_dec   Mean (over exposures) DEC of actual fiber position
#             elon   Ecliptic longitude
#             elat   Ecliptic latitude
#             glon   Galactic longitude
#             glat   Galactic latitude
#               id   Arbitrary primary key composed from targetid, survey, prog
#                    ram. NOTE: this column is stored as a NUMERIC(39,0) dataty
#                    pe.
#         targetid   Unique DESI target ID
#    coadd_exptime   Sum of the exposure times contributing to the coadd for th
#                    is target
#     mean_delta_x   Mean (over exposures) fiber difference between measured an
#                    d requested CS5 X location on focal plane
#      rms_delta_x   RMS (over exposures) of the fiber difference between measu
#                    red and requested CS5 X location on focal plane
#     mean_delta_y   Mean (over exposures) fiber difference between measured an
#                    d requested CS5 Y location on focal plane
#      rms_delta_y   RMS (over exposures) of the fiber difference between measu
#                    red and requested CS5 Y location on focal plane
#     std_fiber_ra   Standard deviation (over exposures) of RA of actual fiber
#                    position
#    std_fiber_dec   Standard deviation (over exposures) of DEC of actual fiber
#                    position
# mean_psf_to_fiber_specflux   Mean of the PSF_TO_FIBER_SPECFLUX values of the spectra us
#                    ed in the coadd
#  tsnr2_gpbdark_b   GPBDARK B template (S/N)^2
#      tsnr2_elg_b   ELG B template (S/N)^2
# tsnr2_gpbbright_b   GPBBRIGHT B template (S/N)^2
#      tsnr2_lya_b   LYA B template (S/N)^2
#      tsnr2_bgs_b   BGS B template (S/N)^2
# tsnr2_gpbbackup_b   GPBBACKUP B template (S/N)^2
#      tsnr2_qso_b   QSO B template (S/N)^2
#      tsnr2_lrg_b   LRG B template (S/N)^2
#  tsnr2_gpbdark_r   GPBDARK R template (S/N)^2
#      tsnr2_elg_r   ELG R template (S/N)^2
# tsnr2_gpbbright_r   GPBBRIGHT R template (S/N)^2
#      tsnr2_lya_r   LYA R template (S/N)^2
#      tsnr2_bgs_r   BGS R template (S/N)^2
# tsnr2_gpbbackup_r   GPBBACKUP R template (S/N)^2
#      tsnr2_qso_r   QSO R template (S/N)^2
#      tsnr2_lrg_r   LRG R template (S/N)^2
#  tsnr2_gpbdark_z   GPBDARK Z template (S/N)^2
#      tsnr2_elg_z   ELG Z template (S/N)^2
# tsnr2_gpbbright_z   GPBBRIGHT Z template (S/N)^2
#      tsnr2_lya_z   LYA Z template (S/N)^2
#      tsnr2_bgs_z   BGS Z template (S/N)^2
# tsnr2_gpbbackup_z   GPBBACKUP Z template (S/N)^2
#      tsnr2_qso_z   QSO Z template (S/N)^2
#      tsnr2_lrg_z   LRG Z template (S/N)^2
#    tsnr2_gpbdark   GPBDARK template (S/N)^2 summed over B, R, Z
#        tsnr2_elg   ELG template (S/N)^2 summed over B, R, Z
#  tsnr2_gpbbright   GPBBRIGHT template (S/N)^2 summed over B, R, Z
#        tsnr2_lya   LYA template (S/N)^2 summed over B, R, Z
#        tsnr2_bgs   BGS template (S/N)^2 summed over B, R, Z
#  tsnr2_gpbbackup   GPBBACKUP template (S/N)^2 summed over B, R, Z
#        tsnr2_qso   QSO template (S/N)^2 summed over B, R, Z
#        tsnr2_lrg   LRG template (S/N)^2 summed over B, R, Z
#        random_id   Random ID in the range 0.0 => 100.0 (not unique)
#         spgrpval   Value corresponding to the grouping type indicated in the
#                    spgrp column. For zpix table this is the same as the healp
#                    ix column
#          healpix   HEALPixel containing this location at NSIDE=64 in the NEST
#                    ED scheme
# coadd_fiberstatus   Bitwise AND of the FIBERSTATUS values of the spectra used
#                    in the coadd
#             htm9   Ninth level (~10 arcmin resolution) Hierarchical Triangula
#                    r Mesh index (Szalay et al. 2007)
#          ring256   Ring-scheme HEALPix (Gorski et al. 2005) index with Nsides
#                    =256 (~14 arcmin size)
#         nest4096   Nested-scheme HEALPix (Gorski et al. 2005) index with Nsid
#                    es=4096 (~52 arcsec size)
#            zwarn   Redshift warning bitmask measured by Redrock
#          npixels   Number of unmasked wavelengths that contributed to the red
#                    shift fit
#           ncoeff   Number of Redrock template coefficients
#     coadd_numexp   Number of exposures included in the coadd for this target
#   coadd_numnight   Number of different nights included in the coadd for this
#                    target
#    coadd_numtile   Number of different tiles included in the coadd for this target
#         sv_nspec   Number of coadded spectra for this TARGETID in SV (SV1+2+3)
#       main_nspec   Number of coadded spectra for this TARGETID in Main survey
#       zcat_nspec   Number of coadded spectra for this TARGETID in this zcatalog
#       sv_primary   True/False flag for the primary coadded spectrum in SV (SV
#                    1+2+3)
#     main_primary   True/False flag for the primary coadded spectrum in Main survey
#     zcat_primary   True/False flag for the primary coadded spectrum in this z
#                    catalog
#            spgrp   Type of spectral grouping. For zpix table this is always =
#                    healpix
#          subtype   Spectral subtype
#          program   DESI program type - BRIGHT, DARK, or BACKUP
#         spectype   Spectype from Redrock file
#           survey   Survey name
#         mean_mjd   Mean value of the Modified Julian Date (when the shutter w
#                    as open for exposures used in the coadded spectrum)
#          min_mjd   Minimum value of the Modified Julian Date (when the shutte
#                    r was open for the first exposure used in the coadded spec
#                    trum)
#          max_mjd   Maximum value of the Modified Julian Date (when the shutte
#                    r was open for the last exposure used in the coadded spect
#                    rum)
#       mws_target   Milky Way Survey targeting bits
#   sv1_mws_target   MWS (bright time program) target selection bitmask for SV1
#   sv2_mws_target   MWS (bright time program) target selection bitmask for SV2
#   sv3_mws_target   MWS (bright time program) target selection bitmask for SV3
#      scnd_target   Target selection bitmask for secondary programs
#  sv1_scnd_target   Secondary target selection bitmask for SV1
#  sv2_scnd_target   Secondary target selection bitmask for SV2
#  sv3_scnd_target   Secondary target selection bitmask for SV3
#       bgs_target   BGS (bright time program) target selection bitmask
#   sv1_bgs_target   BGS (bright time program) target selection bitmask for SV1
#   sv2_bgs_target   BGS (bright time program) target selection bitmask for SV2
#   sv3_bgs_target   BGS (bright time program) target selection bitmask for SV3
#      desi_target   Dark survey + calibration targeting bits
#  sv1_desi_target   DESI (dark time program) target selection bitmask for SV1
#  sv2_desi_target   DESI (dark time program) target selection bitmask for SV2
#  sv3_desi_target   DESI (dark time program) target selection bitmask for SV3
#       cmx_target   Target selection bitmask for commissioning
#         desiname   Human-readable identifier of a sky location DESI JXXX.XXXX
#                    [+/-]YY.YYYY, where X,Y=truncated decimal target_ra, targe
#                    t_dec, precise to 0.36 arcsec

# %%
print(qc.schema("desi_dr1.emfit"))
# Out:
# Schema: desi_dr1
#  Table: emfit
#
#      Column Name   Description
#      -----------   -----------
#                z   Redshift of the target
#       prob_broad   Percentage of broad Ha detection in iterations
#   hb_n_amplitude   Amplitude of the Narrow Hb component
# hb_n_amplitude_err   Uncertainty in Amplitude of the Narrow Hb component
#        hb_n_mean   Mean of the Narrow Hb component
#    hb_n_mean_err   Uncertainty in Mean of the Narrow Hb component
#         hb_n_std   Standard Deviation of the Narrow Hb component
#     hb_n_std_err   Uncertainty in Standard Deviation of the Narrow Hb component
#        hb_n_flux   Flux from the Narrow Hb component
#    hb_n_flux_err   Uncertainty in Flux from the Narrow Hb component
#   hb_n_flux_lerr   16th percentile Flux from the Narrow Hb component
#   hb_n_flux_uerr   84th percentile Flux from the Narrow Hb component
#       hb_n_sigma   Width (in km/s) of the Narrow Hb component
#   hb_n_sigma_err   Uncertainty in the Width of the Narrow Hb component
#  hb_n_sigma_lerr   16th percentile width of the Narrow Hb component
#  hb_n_sigma_uerr   84th percentile width of the Narrow Hb component
# hb_out_amplitude   Amplitude of the Outflow Hb component
# hb_out_amplitude_err   Uncertainty in Amplitude of the Outflow Hb component
#      hb_out_mean   Mean of the Outflow Hb component
#  hb_out_mean_err   Uncertainty in Mean of the Outflow Hb component
#       hb_out_std   Standard Deviation of the Outflow Hb component
#   hb_out_std_err   Uncertainty in Standard Deviation of the Outflow Hb component
#      hb_out_flux   Flux from the Outflow Hb component
#  hb_out_flux_err   Uncertainty in Flux from the Outflow Hb component
# hb_out_flux_lerr   16th percentile Flux from the Outflow Hb component
# hb_out_flux_uerr   84th percentile Flux from the Outflow Hb component
#     hb_out_sigma   Width (in km/s) of the Outflow Hb component
# hb_out_sigma_err   Uncertainty in the Width of the Outflow Hb component
# hb_out_sigma_lerr   16th percentile width of the Outflow Hb component
# hb_out_sigma_uerr   84th percentile width of the Outflow Hb component
#   hb_b_amplitude   Amplitude of the Broad Hb component
# hb_b_amplitude_err   Uncertainty in Amplitude of the Broad Hb component
#        hb_b_mean   Mean of the Broad Hb component
#    hb_b_mean_err   Uncertainty in Mean of the Broad Hb component
#         hb_b_std   Standard Deviation of the Broad Hb component
#     hb_b_std_err   Uncertainty in Standard Deviation of the Broad Hb component
#        hb_b_flux   Flux from the Broad Hb component
#    hb_b_flux_err   Uncertainty in Flux from the Broad Hb component
#   hb_b_flux_lerr   16th percentile Flux from the Broad Hb component
#   hb_b_flux_uerr   84th percentile Flux from the Broad Hb component
#       hb_b_sigma   Width (in km/s) of the Broad Hb component
#   hb_b_sigma_err   Uncertainty in the Width of the Broad Hb component
#  hb_b_sigma_lerr   16th percentile width of the Broad Hb component
#  hb_b_sigma_uerr   84th percentile width of the Broad Hb component
#     hb_continuum   Continuum around the Hb components
# hb_continuum_err   Uncertainty in Continuum around the Hb components
#         hb_noise   rms of the Continuum around the Hb components
#         hb_rchi2   Reduced chi2 associated with the Hb+[OIII]4959,5007 Fit
# oiii4959_amplitude   Amplitude of the Narrow [OIII]4959 component
# oiii4959_amplitude_err   Uncertainty in Amplitude of the Narrow [OIII]4959 component
#    oiii4959_mean   Mean of the Narrow [OIII]4959 component
# oiii4959_mean_err   Uncertainty in Mean of the Narrow [OIII]4959 component
#     oiii4959_std   Standard Deviation of the Narrow [OIII]4959 component
# oiii4959_std_err   Uncertainty in Standard Deviation of the Narrow [OIII]4959
#                    component
#    oiii4959_flux   Flux from the Narrow [OIII]4959 component
# oiii4959_flux_err   Uncertainty in Flux from the Narrow [OIII]4959 component
# oiii4959_flux_lerr   16th percentile Flux from the Narrow [OIII]4959 component
# oiii4959_flux_uerr   84th percentile Flux from the Narrow [OIII]4959 component
#   oiii4959_sigma   Width (in km/s) of the Narrow [OIII]4959 component
# oiii4959_sigma_err   Uncertainty in the Width of the Narrow [OIII]4959 component
# oiii4959_sigma_lerr   16th percentile width of the Narrow [OIII]4959 component
# oiii4959_sigma_uerr   84th percentile width of the Narrow [OIII]4959 component
# oiii4959_out_amplitude   Amplitude of the Outflow [OIII]4959 component
# oiii4959_out_amplitude_err   Uncertainty in Amplitude of the Outflow [OIII]4959 component
# oiii4959_out_mean   Mean of the Outflow [OIII]4959 component
# oiii4959_out_mean_err   Uncertainty in Mean of the Outflow [OIII]4959 component
# oiii4959_out_std   Standard Deviation of the Outflow [OIII]4959 component
# oiii4959_out_std_err   Uncertainty in Standard Deviation of the Outflow [OIII]495
#                    9 component
# oiii4959_out_flux   Flux from the Outflow [OIII]4959 component
# oiii4959_out_flux_err   Uncertainty in Flux from the Outflow [OIII]4959 component
# oiii4959_out_flux_lerr   16th percentile Flux from the Outflow [OIII]4959 component
# oiii4959_out_flux_uerr   84th percentile Flux from the Outflow [OIII]4959 component
# oiii4959_out_sigma   Width (in km/s) of the Outflow [OIII]4959 component
# oiii4959_out_sigma_err   Uncertainty in the Width of the Outflow [OIII]4959 component
# oiii4959_out_sigma_lerr   16th percentile width of the Outflow [OIII]4959 component
# oiii4959_out_sigma_uerr   84th percentile width of the Outflow [OIII]4959 component
# oiii5007_amplitude   Amplitude of the Narrow [OIII]5007 component
# oiii5007_amplitude_err   Uncertainty in Amplitude of the Narrow [OIII]5007 component
#    oiii5007_mean   Mean of the Narrow [OIII]5007 component
# oiii5007_mean_err   Uncertainty in Mean of the Narrow [OIII]5007 component
#     oiii5007_std   Standard Deviation of the Narrow [OIII]5007 component
# oiii5007_std_err   Uncertainty in Standard Deviation of the Narrow [OIII]5007
#                    component
#    oiii5007_flux   Flux from the Narrow [OIII]5007 component
# oiii5007_flux_err   Uncertainty in Flux from the Narrow [OIII]5007 component
# oiii5007_flux_lerr   16th percentile Flux from the Narrow [OIII]5007 component
# oiii5007_flux_uerr   84th percentile Flux from the Narrow [OIII]5007 component
#   oiii5007_sigma   Width (in km/s) of the Narrow [OIII]5007 component
# oiii5007_sigma_err   Uncertainty in the Width of the Narrow [OIII]5007 component
# oiii5007_sigma_lerr   16th percentile width of the Narrow [OIII]5007 component
# oiii5007_sigma_uerr   84th percentile width of the Narrow [OIII]5007 component
# oiii5007_out_amplitude   Amplitude of the Outflow [OIII]5007 component
# oiii5007_out_amplitude_err   Uncertainty in Amplitude of the Outflow [OIII]4959 component
# oiii5007_out_mean   Mean of the Outflow [OIII]5007 component
# oiii5007_out_mean_err   Uncertainty in Mean of the Outflow [OIII]5007 component
# oiii5007_out_std   Standard Deviation of the Outflow [OIII]5007 component
# oiii5007_out_std_err   Uncertainty in Standard Deviation of the Outflow [OIII]500
#                    7 component
# oiii5007_out_flux   Flux from the Outflow [OIII]5007 component
# oiii5007_out_flux_err   Uncertainty in Flux from the Outflow [OIII]5007 component
# oiii5007_out_flux_lerr   16th percentile Flux from the Outflow [OIII]5007 component
# oiii5007_out_flux_uerr   84th percentile Flux from the Outflow [OIII]5007 component
# oiii5007_out_sigma   Width (in km/s) of the Outflow [OIII]5007 component
# oiii5007_out_sigma_err   Uncertainty in the Width of the Outflow [OIII]5007 component
# oiii5007_out_sigma_lerr   16th percentile width of the Outflow [OIII]5007 component
# oiii5007_out_sigma_uerr   84th percentile width of the Outflow [OIII]5007 component
#   oiii_continuum   Continuum around the [OIII] components
# oiii_continuum_err   Uncertainty in Continuum around the [OIII] components
#       oiii_noise   rms of the Continuum around the [OIII] components
#       oiii_rchi2   Reduced chi2 associated with the [OIII]4959,5007 Fit
#    hb_oiii_rchi2   Reduced chi2 associated with the Hb+[OIII]4959,5007 Fit
# nii6548_amplitude   Amplitude of the Narrow [NII]6548 component
# nii6548_amplitude_err   Uncertainty in Amplitude of the Narrow [NII]6548 component
#     nii6548_mean   Mean of the Narrow [NII]6548 component
# nii6548_mean_err   Uncertainty in Mean of the Narrow [NII]6548 component
#      nii6548_std   Standard Deviation of the Narrow [NII]6548 component
#  nii6548_std_err   Uncertainty in Standard Deviation of the Narrow [NII]6548
#                    component
#     nii6548_flux   Flux from the Narrow [NII]6548 component
# nii6548_flux_err   Uncertainty in Flux from the Narrow [NII]6548 component
# nii6548_flux_lerr   16th percentile Flux from the Narrow [NII]6548 component
# nii6548_flux_uerr   84th percentile Flux from the Narrow [NII]6548 component
#    nii6548_sigma   Width (in km/s) of the Narrow [NII]6548 component
# nii6548_sigma_err   Uncertainty in the Width of the Narrow [NII]6548 component
# nii6548_sigma_lerr   16th percentile width of the Narrow [NII]6548 component
# nii6548_sigma_uerr   84th percentile width of the Narrow [NII]6548 component
# nii6548_out_amplitude   Amplitude of the Outflow [NII]6548 component
# nii6548_out_amplitude_err   Uncertainty in Amplitude of the Outflow [NII]6548 component
# nii6548_out_mean   Mean of the Outflow [NII]6548 component
# nii6548_out_mean_err   Uncertainty in Mean of the Outflow [NII]6548 component
#  nii6548_out_std   Standard Deviation of the Outflow [NII]6548 component
# nii6548_out_std_err   Uncertainty in Standard Deviation of the Outflow [NII]6548
#                    component
# nii6548_out_flux   Flux from the Outflow [NII]6548 component
# nii6548_out_flux_err   Uncertainty in Flux from the Outflow [NII]6548 component
# nii6548_out_flux_lerr   16th percentile Flux from the Outflow [NII]6548 component
# nii6548_out_flux_uerr   84th percentile Flux from the Outflow [NII]6548 component
# nii6548_out_sigma   Width (in km/s) of the Outflow [NII]6548 component
# nii6548_out_sigma_err   Uncertainty in the Width of the Outflow [NII]6548 component
# nii6548_out_sigma_lerr   16th percentile width of the Outflow [NII]6548 component
# nii6548_out_sigma_uerr   84th percentile width of the Outflow [NII]6548 component
# nii6583_amplitude   Amplitude of the Narrow [NII]6583 component
# nii6583_amplitude_err   Uncertainty in Amplitude of the Narrow [NII]6583 component
#     nii6583_mean   Mean of the Narrow [NII]6583 component
# nii6583_mean_err   Uncertainty in Mean of the Narrow [NII]6583 component
#      nii6583_std   Standard Deviation of the Narrow [NII]6583 component
#  nii6583_std_err   Uncertainty in Standard Deviation of the Narrow [NII]6583
#                    component
#     nii6583_flux   Flux from the Narrow [NII]6583 component
# nii6583_flux_err   Uncertainty in Flux from the Narrow [NII]6583 component
# nii6583_flux_lerr   16th percentile Flux from the Narrow [NII]6583 component
# nii6583_flux_uerr   84th percentile Flux from the Narrow [NII]6583 component
#    nii6583_sigma   Width (in km/s) of the Narrow [NII]6583 component
# nii6583_sigma_err   Uncertainty in the Width of the Narrow [NII]6583 component
# nii6583_sigma_lerr   16th percentile width of the Narrow [NII]6583 component
# nii6583_sigma_uerr   84th percentile width of the Narrow [NII]6583 component
# nii6583_out_amplitude   Amplitude of the Outflow [NII]6583 component
# nii6583_out_amplitude_err   Uncertainty in Amplitude of the Outflow [NII]6583 component
# nii6583_out_mean   Mean of the Outflow [NII]6583 component
# nii6583_out_mean_err   Uncertainty in Mean of the Outflow [NII]6583 component
#  nii6583_out_std   Standard Deviation of the Outflow [NII]6583 component
# nii6583_out_std_err   Uncertainty in Standard Deviation of the Outflow [NII]6583
#                    component
# nii6583_out_flux   Flux from the Outflow [NII]6583 component
# nii6583_out_flux_err   Uncertainty in Flux from the Outflow [NII]6583 component
# nii6583_out_flux_lerr   16th percentile Flux from the Outflow [NII]6583 component
# nii6583_out_flux_uerr   84th percentile Flux from the Outflow [NII]6583 component
# nii6583_out_sigma   Width (in km/s) of the Outflow [NII]6583 component
# nii6583_out_sigma_err   Uncertainty in the Width of the Outflow [NII]6583 component
# nii6583_out_sigma_lerr   16th percentile width of the Outflow [NII]6583 component
# nii6583_out_sigma_uerr   84th percentile width of the Outflow [NII]6583 component
#   ha_n_amplitude   Amplitude of the Narrow Ha component
# ha_n_amplitude_err   Uncertainty in Amplitude of the Narrow Ha component
#        ha_n_mean   Mean of the Narrow Ha component
#    ha_n_mean_err   Uncertainty in Mean of the Narrow Ha component
#         ha_n_std   Standard Deviation of the Narrow Ha component
#     ha_n_std_err   Uncertainty in Standard Deviation of the Narrow Ha component
#        ha_n_flux   Flux from the Narrow Ha component
#    ha_n_flux_err   Uncertainty in Flux from the Narrow Ha component
#   ha_n_flux_lerr   16th percentile Flux from the Narrow Ha component
#   ha_n_flux_uerr   84th percentile Flux from the Narrow Ha component
#       ha_n_sigma   Width (in km/s) of the Narrow Ha component
#   ha_n_sigma_err   Uncertainty in the Width of the Narrow Ha component
#  ha_n_sigma_lerr   16th percentile width of the Narrow Ha component
#  ha_n_sigma_uerr   84th percentile width of the Narrow Ha component
# ha_out_amplitude   Amplitude of the Outflow Ha component
# ha_out_amplitude_err   Uncertainty in Amplitude of the Outflow Ha component
#      ha_out_mean   Mean of the Outflow Ha component
#  ha_out_mean_err   Uncertainty in Mean of the Outflow Ha component
#       ha_out_std   Standard Deviation of the Outflow Ha component
#   ha_out_std_err   Uncertainty in Standard Deviation of the Outflow Ha component
#      ha_out_flux   Flux from the Outflow Ha component
#  ha_out_flux_err   Uncertainty in Flux from the Outflow Ha component
# ha_out_flux_lerr   16th percentile Flux from the Outflow Ha component
# ha_out_flux_uerr   84th percentile Flux from the Outflow Ha component
#     ha_out_sigma   Width (in km/s) of the Outflow Ha component
# ha_out_sigma_err   Uncertainty in the Width of the Outflow Ha component
# ha_out_sigma_lerr   16th percentile width of the Outflow Ha component
# ha_out_sigma_uerr   84th percentile width of the Outflow Ha component
#   ha_b_amplitude   Amplitude of the Broad Ha component
# ha_b_amplitude_err   Uncertainty in Amplitude of the Broad Ha component
#        ha_b_mean   Mean of the Broad Ha component
#    ha_b_mean_err   Uncertainty in Mean of the Broad Ha component
#         ha_b_std   Standard Deviation of the Broad Ha component
#     ha_b_std_err   Uncertainty in Standard Deviation of the Broad Ha component
#        ha_b_flux   Flux from the Broad Ha component
#    ha_b_flux_err   Uncertainty in Flux from the Broad Ha component
#   ha_b_flux_lerr   16th percentile Flux from the Broad Ha component
#   ha_b_flux_uerr   84th percentile Flux from the Broad Ha component
#       ha_b_sigma   Width (in km/s) of the Broad Ha component
#   ha_b_sigma_err   Uncertainty in the Width of the Broad Ha component
#  ha_b_sigma_lerr   16th percentile width of the Broad Ha component
#  ha_b_sigma_uerr   84th percentile width of the Broad Ha component
# nii_ha_continuum   Continuum around the [NII]+Ha components
# nii_ha_continuum_err   Uncertainty in Continuum around the [NII]+Ha components
#     nii_ha_noise   rms of the Continuum around the [NII]+Ha components
#     nii_ha_rchi2   Reduced chi2 associated with the [NII]6548,6583+Ha Fit
# sii6716_amplitude   Amplitude of the Narrow [SII]6716 component
# sii6716_amplitude_err   Uncertainty in Amplitude of the Narrow [SII]6716 component
#     sii6716_mean   Mean of the Narrow [SII]6716 component
# sii6716_mean_err   Uncertainty in Mean of the Narrow [SII]6716 component
#      sii6716_std   Standard Deviation of the Narrow [SII]6716 component
#  sii6716_std_err   Uncertainty in Standard Deviation of the Narrow [SII]6716
#                    component
#     sii6716_flux   Flux from the Narrow [SII]6716 component
# sii6716_flux_err   Uncertainty in Flux from the Narrow [SII]6716 component
# sii6716_flux_lerr   16th percentile Flux from the Narrow [SII]6716 component
# sii6716_flux_uerr   84th percentile Flux from the Narrow [SII]6716 component
#    sii6716_sigma   Width (in km/s) of the Narrow [SII]6716 component
# sii6716_sigma_err   Uncertainty in the Width of the Narrow [SII]6716 component
# sii6716_sigma_lerr   16th percentile width of the Narrow [SII]6716 component
# sii6716_sigma_uerr   84th percentile width of the Narrow [SII]6716 component
# sii6716_out_amplitude   Amplitude of the Outflow [SII]6716 component
# sii6716_out_amplitude_err   Uncertainty in Amplitude of the Outflow [SII]6716 component
# sii6716_out_mean   Mean of the Outflow [SII]6716 component
# sii6716_out_mean_err   Uncertainty in Mean of the Outflow [SII]6716 component
#  sii6716_out_std   Standard Deviation of the Outflow [SII]6716 component
# sii6716_out_std_err   Uncertainty in Standard Deviation of the Outflow [SII]6716
#                    component
# sii6716_out_flux   Flux from the Outflow [SII]6716 component
# sii6716_out_flux_err   Uncertainty in Flux from the Outflow [SII]6716 component
# sii6716_out_flux_lerr   16th percentile Flux from the Outflow [SII]6716 component
# sii6716_out_flux_uerr   84th percentile Flux from the Outflow [SII]6716 component
# sii6716_out_sigma   Width (in km/s) of the Outflow [SII]6716 component
# sii6716_out_sigma_err   Uncertainty in the Width of the Outflow [SII]6716 component
# sii6716_out_sigma_lerr   16th percentile width of the Outflow [SII]6716 component
# sii6716_out_sigma_uerr   84th percentile width of the Outflow [SII]6716 component
# sii6731_amplitude   Amplitude of the Narrow [SII]6731 component
# sii6731_amplitude_err   Uncertainty in Amplitude of the Narrow [SII]6731 component
#     sii6731_mean   Mean of the Narrow [SII]6731 component
# sii6731_mean_err   Uncertainty in Mean of the Narrow [SII]6731 component
#      sii6731_std   Standard Deviation of the Narrow [SII]6731 component
#  sii6731_std_err   Uncertainty in Standard Deviation of the Narrow [SII]6731
#                    component
#     sii6731_flux   Flux from the Narrow [SII]6731 component
# sii6731_flux_err   Uncertainty in Flux from the Narrow [SII]6731 component
# sii6731_flux_lerr   16th percentile Flux from the Narrow [SII]6731 component
# sii6731_flux_uerr   84th percentile Flux from the Narrow [SII]6731 component
#    sii6731_sigma   Width (in km/s) of the Narrow [SII]6731 component
# sii6731_sigma_err   Uncertainty in the Width of the Narrow [SII]6731 component
# sii6731_sigma_lerr   16th percentile width of the Narrow [SII]6731 component
# sii6731_sigma_uerr   84th percentile width of the Narrow [SII]6731 component
# sii6731_out_amplitude   Amplitude of the Outflow [SII]6731 component
# sii6731_out_amplitude_err   Uncertainty in Amplitude of the Outflow [SII]6731 component
# sii6731_out_mean   Mean of the Outflow [SII]6731 component
# sii6731_out_mean_err   Uncertainty in Mean of the Outflow [SII]6731 component
#  sii6731_out_std   Standard Deviation of the Outflow [SII]6731 component
# sii6731_out_std_err   Uncertainty in Standard Deviation of the Outflow [SII]6731
#                    component
# sii6731_out_flux   Flux from the Outflow [SII]6731 component
# sii6731_out_flux_err   Uncertainty in Flux from the Outflow [SII]6731 component
# sii6731_out_flux_lerr   16th percentile Flux from the Outflow [SII]6731 component
# sii6731_out_flux_uerr   84th percentile Flux from the Outflow [SII]6731 component
# sii6731_out_sigma   Width (in km/s) of the Outflow [SII]6731 component
# sii6731_out_sigma_err   Uncertainty in the Width of the Outflow [SII]6731 component
# sii6731_out_sigma_lerr   16th percentile width of the Outflow [SII]6731 component
# sii6731_out_sigma_uerr   84th percentile width of the Outflow [SII]6731 component
#    sii_continuum   Continuum around the [SII] components
# sii_continuum_err   Uncertainty in Continuum around the [SII] components
#        sii_noise   rms of the Continuum around the [SII] components
#        sii_rchi2   Reduced chi2 associated with the [SII]6717,6731 Fit
# nii_ha_sii_rchi2   Reduced chi2 associated with the [NII]6548,6583+Ha+[SII]67
#                    17,6731 Fit
#         targetid   Unique identifier of the DESI target
#  hb_n_sigma_flag   Flag regarding instrumental resolution correction for Narrow Hb
# hb_out_sigma_flag   Flag regarding instrumental resolution correction for Outf
#                    low Hb
#  hb_b_sigma_flag   Flag regarding instrumental resolution correction for Broad Hb
#          hb_ndof   Number of Degrees of Freedom associated with the Hb Fit
# oiii4959_sigma_flag   Flag regarding instrumental resolution correction for Narr
#                    ow [OIII]4959
# oiii4959_out_sigma_flag   Flag regarding instrumental resolution correction for Outf
#                    low [OIII]4959
# oiii5007_sigma_flag   Flag regarding instrumental resolution correction for Narr
#                    ow [OIII]5007
# oiii5007_out_sigma_flag   Flag regarding instrumental resolution correction for Outf
#                    low [OIII]5007
#        oiii_ndof   Number of Degrees of Freedom associated with the [OIII]495
#                    9,5007 Fit
#     hb_oiii_ndof   Number of Degrees of Freedom associated with the Hb+[OIII]
#                    4959,5007 Fit
# nii6548_sigma_flag   Flag regarding instrumental resolution correction for Narr
#                    ow [NII]6548
# nii6548_out_sigma_flag   Flag regarding instrumental resolution correction for Outf
#                    low [NII]6548
# nii6583_sigma_flag   Flag regarding instrumental resolution correction for Narr
#                    ow [NII]6583
# nii6583_out_sigma_flag   Flag regarding instrumental resolution correction for Outf
#                    low [NII]6583
#  ha_n_sigma_flag   Flag regarding instrumental resolution correction for Narrow Ha
# ha_out_sigma_flag   Flag regarding instrumental resolution correction for Outf
#                    low Ha
#  ha_b_sigma_flag   Flag regarding instrumental resolution correction for Broad Ha
#      nii_ha_ndof   Number of Degrees of Freedom associated with the [NII]6548
#                    ,6583+Ha Fit
# sii6716_sigma_flag   Flag regarding instrumental resolution correction for Narr
#                    ow [SII]6716
# sii6716_out_sigma_flag   Flag regarding instrumental resolution correction for Outf
#                    low [SII]6716
# sii6731_sigma_flag   Flag regarding instrumental resolution correction for Narr
#                    ow [SII]6731
# sii6731_out_sigma_flag   Flag regarding instrumental resolution correction for Outf
#                    low [SII]6731
#         sii_ndof   Number of Degrees of Freedom associated with the [SII]6716
#                    ,6731 Fit
#  nii_ha_sii_ndof   Number of Degrees of Freedom associated with the [NII]6548
#                    ,6583 + Ha + [SII]6717,6731 Fit
#          healpix   Healpix number of the target
#        random_id   Random ID in the range 0.0 => 100.0 (not unique)
#    oiii_dbl_flag   Flag regarding whether the [OIII] emission has double narr
#                    ow-peak Gaussian components
#     sii_dbl_flag   Flag regarding whether the [SII] (and therefore [NII], HA,
#                    and HB) emission has double narrow-peak Gaussian componen
#                    ts
#          program   Observing Program dark or bright or backup or other
#           survey   DESI Survey of the spectra main or special or sv1 or sv2 o
#                    r sv3 or cmx
#         specprod   Spectral Production Pipeline fuji
